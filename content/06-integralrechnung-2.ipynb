# %% [markdown]
# # Integralrechnung
#
#
# ## Imports
#
# Führen Sie zunächst den folgenden Code aus, um die relevanten Bibliotheken einzubinden.

# %%
from pylab import *
from scipy import *
from numpy import *
from scipy.optimize import newton
import scipy.integrate

# %% [markdown]
# ## Quadraturformeln

# %% [markdown]
# Betrachten Sie die Funktion $f(x)=1/x$ und das Integral $\int_2^4\frac 1x dx = ln(4)-ln(2)=ln(2)=0.69314718056$.
#
# Implementieren Sie drei Funktionen, um die das Integral numerisch zu berechnen: Sie nehmen (wie in der ersten Aufgabe) den linken Funktionswert, die Annäherung durch eine lineare Funktion und die 3-Punkt-Simpson-Formel. Vergleichen Sie die Ergebnisse für $n=10,100$ und $1000$.
#
# Zum Vergleich wird die numerische Integration mit scipy.integrate.quad genutzt, die eine numerische Integration bereitstellt.

# %%
# Parameter definieren
n = 10
f = lambda x: (-5*x**2 + x**4)*exp(-.2*x**2)
a = -8
b = 8

x = linspace(a,b,1000)
plot(x, f(x))
xlim(a,b)
# Out:
# (-8.0, 8.0)

# %%
# Integral über Rechtecke
def integral_box(f, a, b, n):
    # TODO
    return 0


# Integral mit linearer Näherung
def integral_linear(f, a, b, n):
    # TODO
    return 0


# Integral mit 3-Punkt-Simpson Regel
def integral_simpson(f, a, b, n):
    # TODO
    return 0



# Ergebnisse berechnen und ausgeben
exact = integrate.quad(f, a, b)[0]
print("Exakter Wert:", exact)
print("Rechtecke: ", integral_box(f, a, b, n), integral_box(f, a, b, n) - exact)
print(
    "Lineare Funktion:",
    integral_linear(f, a, b, n),
    integral_linear(f, a, b, n) - exact,
)
print(
    "Simpson-Regel:", integral_simpson(f, a, b, n), integral_simpson(f, a, b, n) - exact
)
# Out:
# Exakter Wert: 24.763441550285876
# Rechtecke:  0 -24.763441550285876
# Lineare Funktion: 0 -24.763441550285876
# Simpson-Regel: 0 -24.763441550285876
